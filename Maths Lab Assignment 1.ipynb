# %% [markdown]
# # COMPUTATIONAL LINEAR ALGEBRA AND OPTIMIZATION

# %% [markdown]
# #### <font color='green'> Name     : Akash Kalluvilayil Venugopalan</font>
# #### <font color='green'> Roll.No  : AM.EN.P2ARI20001</font>

# %% [markdown]
# ## <font color='red'> LAB WORK: LAB ASSIGNMENT 1</font>

# %%
import sympy
import numpy as np
import matplotlib.pyplot as plt
import sympy.plotting as plt3

# %% [markdown]
# #### 1) Create matrices and display:

# %%
A = sympy.Matrix([[2, -1], [-1, 2]])
A
# Out:
# Matrix([
# [ 2, -1],
# [-1,  2]])

# %%
B = sympy.Matrix([[1, 2, 3], [4, 5, 6], [7, 8, 9]])
B
# Out:
# Matrix([
# [1, 2, 3],
# [4, 5, 6],
# [7, 8, 9]])

# %%
C = sympy.Matrix([[1, 0, 1], [1, 1, 2]])
C
# Out:
# Matrix([
# [1, 0, 1],
# [1, 1, 2]])

# %% [markdown]
# #### 2) Print dimensions of A, B and C

# %%
print("Dimension of A:", A.shape)
print("Dimension of B:", B.shape)
print("Dimension of C:", C.shape)
# Out:
# Dimension of A: (2, 2)
# Dimension of B: (3, 3)
# Dimension of C: (2, 3)

# %%
D = sympy.Matrix([[1, 0, 1], [4, 2, 4], [3, 4, 6]])
D
# Out:
# Matrix([
# [1, 0, 1],
# [4, 2, 4],
# [3, 4, 6]])

# %% [markdown]
# #### 3) Create another 3x3 matrix D. Perform B + D and B x D.

# %% [markdown]
# ADD (B + D):

# %%
B + D
# Out:
# Matrix([
# [ 2,  2,  4],
# [ 8,  7, 10],
# [10, 12, 15]])

# %% [markdown]
# Multiply (B * D):

# %%
B * D
# Out:
# Matrix([
# [18, 16, 27],
# [42, 34, 60],
# [66, 52, 93]])

# %% [markdown]
# #### 4) Consider following system of eqns.
#
# $2x - y = 1$
#
# $-x + 2y = 4$
#
#
# Plot Row Picture and Column Picture

# %%
x = np.linspace(-3,3,100)
plt.figure(figsize=(10,8))
plt.plot(x, 2*x-1)
plt.plot(x, ((x+4)/2))
plt.show()

# %%
plt.figure(figsize=(20,10))
ax = plt.axes()

ax.arrow(0, 0, 2, -1, length_includes_head=True, head_width=0.2, head_length=0.5, fc='lightblue', ec='black')

ax.arrow(0, 0, -1, 2, length_includes_head=True, head_width=0.2, head_length=0.5, fc='lightgreen', ec='black')

ax.arrow(0, 0, 1, 4, length_includes_head=True, head_width=0.2, head_length=0.5, fc='red', ec='black')

plt.grid()

plt.xlim(-5,5)
plt.ylim(-5,5)

plt.title('Vector view',fontsize=10)
plt.show();

# %%
plt.figure(figsize=(20,10))
ax = plt.axes()

ax.arrow(0, 0, 2, -1, length_includes_head=True, head_width=0.2, head_length=0.5, fc='lightblue', ec='black')

ax.arrow(2, -1, 2, -1, length_includes_head=True, head_width=0.2, head_length=0.5, fc='lightgreen', ec='black')

ax.arrow(4, -2, -1, 2, length_includes_head=True, head_width=0.2, head_length=0.5, fc='lightgreen', ec='black')

ax.arrow(3, 0, -1, 2, length_includes_head=True, head_width=0.2, head_length=0.5, fc='lightgreen', ec='black')

ax.arrow(2, 2, -1, 2, length_includes_head=True, head_width=0.2, head_length=0.5, fc='lightgreen', ec='black')

ax.arrow(0, 0, 1, 4, length_includes_head=True, head_width=0.2,head_length=0.5, fc='red', ec='black')

plt.grid()

plt.xlim(-5,5)
plt.ylim(-5,5)

plt.title('Vector view',fontsize=10)
plt.show();

# %% [markdown]
# Form Matrix Picture and plot Row Picture:
#
# $2x - y = 0$
#
# $-x + 2y - z = -1$
#
# $-3y + 4z = 4$

# %% [markdown]
# Form matrix a:

# %%
a = sympy.Matrix([[2, -1, 0], [-1, 2, -1], [0, -3, 4]])
a
# Out:
# Matrix([
# [ 2, -1,  0],
# [-1,  2, -1],
# [ 0, -3,  4]])

# %% [markdown]
# Form matrix b:

# %%
b = sympy.Matrix([[0], [-1], [4]])
b
# Out:
# Matrix([
# [ 0],
# [-1],
# [ 4]])

# %% [markdown]
# Form matrix x:

# %%
x, y, z = sympy.symbols('x, y, z')

# %%
X = sympy.Matrix([[x], [y], [z]])
X
# Out:
# Matrix([
# [x],
# [y],
# [z]])

# %%
sympy.Eq(a * X, b)
# Out:
# Eq(Matrix([
# [     2*x - y],
# [-x + 2*y - z],
# [  -3*y + 4*z]]), Matrix([
# [ 0],
# [-1],
# [ 4]]))

# %% [markdown]
# Form row picture:

# %%
plt3.plot3d((2*x-1*y, (x,-5,5), (y,-5,5)), (-x+2*y+1, (x,-5,5), (y,-5,5)), (-3*y-4, (x,-5,5), (y,-5,5)));
